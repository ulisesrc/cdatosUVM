# %% [markdown]
# Importar librerias

# %%
import pandas as pd

# %% [markdown]
# Leer .csv desde la url con pandas: [www.football-data.com.uk/data.php](https://www.football-data.co.uk/data.php)

# %%
df_PL = pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/E0.csv')

# %%
df_PL
# Out:
#     Div        Date   Time       HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    E0  11/08/2023  20:00        Burnley        Man City     0     3   A
# 1    E0  12/08/2023  12:30        Arsenal   Nott'm Forest     2     1   H
# 2    E0  12/08/2023  15:00    Bournemouth        West Ham     1     1   D
# 3    E0  12/08/2023  15:00       Brighton           Luton     4     1   H
# 4    E0  12/08/2023  15:00        Everton          Fulham     0     1   A
# ..   ..         ...    ...            ...             ...   ...   ...  ..
# 262  E0  02/03/2024  15:00  Nott'm Forest       Liverpool     0     1   A
# 263  E0  02/03/2024  15:00      Tottenham  Crystal Palace     3     1   H
# 264  E0  02/03/2024  17:30          Luton     Aston Villa     2     3   A
# 265  E0  03/03/2024  13:00        Burnley     Bournemouth     0     2   A
# 266  E0  03/03/2024  15:30       Man City      Man United     3     1   H
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# ...

# %% [markdown]
# Estructura: https://www.football-data.co.uk/mmz4281/ "Temporada" / "Nombre Liga".csv
#           https://www.football-data.co.uk/mmz4281/2324/E0.csv

# %% [markdown]
# https://www.football-data.co.uk/mmz4281/"+"2324"/"+"E0" +".cvs"

# %%
"https://www.football-data.co.uk/mmz4281/" + "2324" + "/" + "E0" + ".csv"
# Out:
# 'https://www.football-data.co.uk/mmz4281/2324/E0.csv'

# %% [markdown]
# Link raiz

# %%
root = "https://www.football-data.co.uk/mmz4281/"

# %% [markdown]
# lista de ligas

# %%
leagues = ['E0','E1','E2','E3','EC']

#bucle for
for league in leagues:
    df = pd.read_csv(root + '2324' + '/' + league + '.csv' )

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Div        Date   Time      HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    EC  05/08/2023  15:00     Aldershot   Oxford City     5     2   H     3
# 1    EC  05/08/2023  15:00    Altrincham   Dag and Red     1     1   D     0
# 2    EC  05/08/2023  15:00        Barnet    Hartlepool     3     2   H     1
# 3    EC  05/08/2023  15:00  Chesterfield       Dorking     4     3   H     1
# 4    EC  05/08/2023  15:00     Gateshead  Boreham Wood     2     2   D     2
# ..   ..         ...    ...           ...           ...   ...   ...  ..   ...
# 426  EC  02/03/2024  15:00         Fylde    Maidenhead     4     1   H     1
# 427  EC  02/03/2024  15:00    Hartlepool        Barnet     1     2   A     0
# 428  EC  02/03/2024  15:00        Oldham      Southend     1     1   D     0
# 429  EC  02/03/2024  15:00   Oxford City     Aldershot     1     2   A     1
# 430  EC  02/03/2024  15:00          York    Wealdstone     2     3   A     1
#
# ...

# %%
leagues = ['E0','E1','E2','E3','EC']
frames = []

#bucle for
for league in leagues:
    df = pd.read_csv(root + '2324' + '/' + league + '.csv' )
    frames.append(df)

# %%
len(frames)
# Out:
# 5

# %%
frames[2]
# Out:
#     Div        Date   Time     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E2  05/08/2023  15:00     Barnsley       Port Vale     7     0   H     2
# 1    E2  05/08/2023  15:00    Blackpool          Burton     2     0   H     2
# 2    E2  05/08/2023  15:00       Bolton         Lincoln     3     0   H     1
# 3    E2  05/08/2023  15:00    Cambridge          Oxford     2     0   H     2
# 4    E2  05/08/2023  15:00     Carlisle  Fleetwood Town     1     1   D     1
# ..   ..         ...    ...          ...             ...   ...   ...  ..   ...
# 419  E2  02/03/2024  15:00  Northampton        Charlton     1     1   D     0
# 420  E2  02/03/2024  15:00    Peterboro          Exeter     2     1   H     1
# 421  E2  02/03/2024  15:00   Portsmouth          Oxford     2     1   H     1
# 422  E2  02/03/2024  15:00   Shrewsbury       Blackpool     0     2   A     0
# 423  E2  02/03/2024  15:00      Wycombe        Barnsley     2     4   A     1
#
# ...
